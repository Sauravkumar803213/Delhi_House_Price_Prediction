# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Delhi_v2.csv')
data.head()
# Out:
#    Unnamed: 0       price                                            Address  \
# 0           0   5600000.0                  Noida Extension, Noida, Delhi NCR
# 1           1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2           2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 3           3   3810000.0  Link Road, F Block, Sector 50, Noida, Uttar Pr...
# 4           4   6200000.0  Jaypee Pavilion Court Sector 128, Noida, Secto...
#
#      area   latitude  longitude  Bedrooms  Bathrooms  Balcony  \
# 0  1350.0  28.608850  77.460560       3.0        3.0      NaN
# 1  1490.0  28.374236  76.952416       3.0        3.0      NaN
# 2  2385.0  28.645769  77.385110       4.0        5.0      NaN
# 3  1050.0  28.566914  77.436434       2.0        2.0      3.0
# 4  1350.0  28.520732  77.356491       2.0        2.0      3.0
#
#                Status      neworold  parking Furnished_status  Lift  \
# ...

# %%
data['type_of_building'].unique()
# Out:
# array(['Flat', 'Individual House'], dtype=object)

# %%
data.shape
# Out:
# (7738, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   Address           7738 non-null   object
#  3   area              7738 non-null   float64
#  4   latitude          7738 non-null   float64
#  5   longitude         7738 non-null   float64
#  6   Bedrooms          7738 non-null   float64
#  7   Bathrooms         7738 non-null   float64
#  8   Balcony           5166 non-null   float64
#  9   Status            7164 non-null   object
#  10  neworold          7738 non-null   object
#  11  parking           2612 non-null   float64
#  12  Furnished_status  4124 non-null   object
#  13  Lift              1733 non-null   float64
#  14  Landmarks         2759 non-null   object
#  15  type_of_building  7738 non-null   object
# ...

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# Unnamed: 0
# 0       1
# 5198    1
# 5166    1
# 5165    1
# 5164    1
#        ..
# 2575    1
# 2574    1
# 2573    1
# 2572    1
# 7737    1
# Name: count, Length: 7738, dtype: int64
# ********************
# price
# 4500000.0    290
# 3500000.0    252
# 4000000.0    247
# 6000000.0    243
# 5500000.0    223
#             ...
# 6860000.0      1
# 5290000.0      1
# 8450000.0      1
# 7670000.0      1
# 4510000.0      1
# Name: count, Length: 584, dtype: int64
# ********************
# Address
# Raj Nagar Extension, Ghaziabad, Delhi NCR                                     163
# Indirapuram, Ghaziabad, Delhi NCR                                             152
# Greater Noida West, Greater Noida, Delhi NCR                                  100
# Noida Extension, Noida, Delhi NCR                                              63
# NH 24, Ghaziabad, Delhi NCR                                                    61
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0             0
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             2572
# Status               574
# neworold               0
# parking             5126
# Furnished_status    3614
# Lift                6005
# Landmarks           4979
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0','latitude','longitude','Balcony','Status','neworold','parking','Furnished_status','Lift','Landmarks','desc'],inplace=True)

# %%
data.head()
# Out:
#         price                                            Address    area  \
# 0   5600000.0                  Noida Extension, Noida, Delhi NCR  1350.0
# 1   8800000.0                      Sector 79, Gurgaon, Delhi NCR  1490.0
# 2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR  2385.0
# 3   3810000.0  Link Road, F Block, Sector 50, Noida, Uttar Pr...  1050.0
# 4   6200000.0  Jaypee Pavilion Court Sector 128, Noida, Secto...  1350.0
#
#    Bedrooms  Bathrooms type_of_building   Price_sqft
# 0       3.0        3.0             Flat  4148.148148
# 1       3.0        3.0             Flat  5906.040268
# 2       4.0        5.0             Flat  6918.238994
# 3       2.0        2.0             Flat  3628.571429
# 4       2.0        2.0             Flat  4592.592593

# %%
data.describe()
# Out:
#               price         area     Bedrooms    Bathrooms    Price_sqft
# count  7.738000e+03  7738.000000  7738.000000  7738.000000   7738.000000
# mean   8.320635e+06  1409.506591     2.708193     2.501163   5543.660241
# std    7.223197e+06   718.929581     0.877026     0.867050   2408.659307
# min    1.700000e+06   501.000000     2.000000     2.000000   2100.000000
# 25%    4.200000e+06   990.000000     2.000000     2.000000   3950.986915
# 50%    6.000000e+06  1250.000000     3.000000     2.000000   4972.674332
# 75%    9.500000e+06  1650.000000     3.000000     3.000000   6350.638693
# max    8.500000e+07  9500.000000    10.000000    10.000000  44378.698225

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             7738 non-null   float64
#  1   Address           7738 non-null   object
#  2   area              7738 non-null   float64
#  3   Bedrooms          7738 non-null   float64
#  4   Bathrooms         7738 non-null   float64
#  5   type_of_building  7738 non-null   object
#  6   Price_sqft        7738 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 423.3+ KB

# %%
data['location'] = (
    data['Address']
    .str.split(',')
    .apply(lambda x: ', '.join([x[-3].strip(), x[-2].strip()]) if len(x) >= 3 else None)
)

# %%
data.head()
# Out:
#         price                                            Address    area  \
# 0   5600000.0                  Noida Extension, Noida, Delhi NCR  1350.0
# 1   8800000.0                      Sector 79, Gurgaon, Delhi NCR  1490.0
# 2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR  2385.0
# 3   3810000.0  Link Road, F Block, Sector 50, Noida, Uttar Pr...  1050.0
# 4   6200000.0  Jaypee Pavilion Court Sector 128, Noida, Secto...  1350.0
#
#    Bedrooms  Bathrooms type_of_building   Price_sqft                 location
# 0       3.0        3.0             Flat  4148.148148   Noida Extension, Noida
# 1       3.0        3.0             Flat  5906.040268       Sector 79, Gurgaon
# 2       4.0        5.0             Flat  6918.238994      Vaishali, Ghaziabad
# 3       2.0        2.0             Flat  3628.571429  Sector 1, Greater Noida
# 4       2.0        2.0             Flat  4592.592593        Sector 128, Noida

# %%
data.drop(columns=['Address'],inplace=True)

# %%
data.head()
# Out:
#         price    area  Bedrooms  Bathrooms type_of_building   Price_sqft  \
# 0   5600000.0  1350.0       3.0        3.0             Flat  4148.148148
# 1   8800000.0  1490.0       3.0        3.0             Flat  5906.040268
# 2  16500000.0  2385.0       4.0        5.0             Flat  6918.238994
# 3   3810000.0  1050.0       2.0        2.0             Flat  3628.571429
# 4   6200000.0  1350.0       2.0        2.0             Flat  4592.592593
#
#                   location
# 0   Noida Extension, Noida
# 1       Sector 79, Gurgaon
# 2      Vaishali, Ghaziabad
# 3  Sector 1, Greater Noida
# 4        Sector 128, Noida

# %%
data['location'].value_counts()
# Out:
# location
# Raj Nagar Extension, Ghaziabad         296
# Indirapuram, Ghaziabad                 262
# Greater Noida West, Greater Noida      181
# Noida Extension, Noida                 160
# NH 24, Ghaziabad                       137
#                                       ...
# Bhagwan Das Nagar, New Delhi - West      1
# Tilpata karanwas, Greater Noida          1
# Model Town West, Ghaziabad               1
# HUDA Staff Colony, Faridabad             1
# Sector 152, Noida                        1
# Name: count, Length: 1172, dtype: int64

# %%
data['location'] = data['location'].str.strip()

# %%
data['location'].isna().sum()
# Out:
# np.int64(4)

# %%
data['location'] = data['location'].fillna('Raj Nagar Extension, Ghaziabad ')

# %%
location_counts = data['location'].value_counts()

data['location'] = data['location'].apply(
    lambda x: x if location_counts[x] >= 10 else 'other'
)

# %%
data['location'].value_counts()
# Out:
# location
# other                                2521
# Raj Nagar Extension, Ghaziabad        296
# Indirapuram, Ghaziabad                262
# Greater Noida West, Greater Noida     181
# Noida Extension, Noida                160
#                                      ...
# Sector 70, Noida                       10
# South City 1, Gurgaon                  10
# Sector-Pi, Greater Noida               10
# Pitampura, New Delhi - West            10
# Laxmi Nagar, New Delhi - East          10
# Name: count, Length: 183, dtype: int64

# %%
data.describe()
# Out:
#               price         area     Bedrooms    Bathrooms    Price_sqft
# count  7.738000e+03  7738.000000  7738.000000  7738.000000   7738.000000
# mean   8.320635e+06  1409.506591     2.708193     2.501163   5543.660241
# std    7.223197e+06   718.929581     0.877026     0.867050   2408.659307
# min    1.700000e+06   501.000000     2.000000     2.000000   2100.000000
# 25%    4.200000e+06   990.000000     2.000000     2.000000   3950.986915
# 50%    6.000000e+06  1250.000000     3.000000     2.000000   4972.674332
# 75%    9.500000e+06  1650.000000     3.000000     3.000000   6350.638693
# max    8.500000e+07  9500.000000    10.000000    10.000000  44378.698225

# %%
(data['area']/data['Bedrooms']).describe()
# Out:
# count    7738.000000
# mean      515.630662
# std       147.378756
# min        50.700000
# 25%       425.000000
# 50%       500.000000
# 75%       590.000000
# max      1900.000000
# dtype: float64

# %%
data.nlargest(10, 'price')[['price', 'area', 'Bedrooms', 'Bathrooms', 'location']]
# Out:
#            price    area  Bedrooms  Bathrooms               location
# 6614  85000000.0  5330.0       5.0        5.0                  other
# 6636  82500000.0  5330.0       5.0        6.0                  other
# 95    82000000.0  5495.0       5.0        6.0                  other
# 43    80000000.0  5571.0       5.0        5.0     Sector 48, Gurgaon
# 197   79000000.0  7200.0       5.0        6.0                  other
# 1328  74500000.0  6750.0       4.0        4.0                  other
# 6742  70000000.0  2700.0       4.0        4.0                  other
# 6871  70000000.0  9500.0       5.0        6.0                  other
# 2984  67500000.0  6285.0       5.0        7.0                  other
# 6975  67500000.0  5000.0       5.0        6.0  South City 1, Gurgaon

# %%
def remove_outliers_sqft(df):
    df_output = pd.DataFrame()

    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.Price_sqft)
        st = np.std(subdf.Price_sqft)

        gen_df = subdf[
            (subdf.Price_sqft > (m - 1.5*st)) &
            (subdf.Price_sqft <= (m + 1.5*st))
        ]

        df_output = pd.concat([df_output, gen_df], ignore_index=True)

    return df_output

data = remove_outliers_sqft(data)
data.describe()
# Out:
#               price         area     Bedrooms    Bathrooms    Price_sqft
# count  6.931000e+03  6931.000000  6931.000000  6931.000000   6931.000000
# mean   7.791451e+06  1388.066080     2.674506     2.467609   5315.059200
# std    6.218619e+06   697.329365     0.838442     0.830643   1863.424349
# min    1.850000e+06   501.000000     2.000000     2.000000   2100.000000
# 25%    4.100000e+06   980.000000     2.000000     2.000000   3906.976744
# 50%    6.000000e+06  1240.000000     3.000000     2.000000   4914.285714
# 75%    9.000000e+06  1607.500000     3.000000     3.000000   6148.417283
# max    7.900000e+07  9500.000000    10.000000    10.000000  14827.586207

# %%
data.nlargest(10, 'area')[['price', 'area', 'Bedrooms', 'Bathrooms', 'location']]
# Out:
#            price    area  Bedrooms  Bathrooms               location
# 6710  70000000.0  9500.0       5.0        6.0                  other
# 4629  45000000.0  9000.0      10.0       10.0                  other
# 2579  40000000.0  8000.0       7.0        8.0  Sector 21C, Faridabad
# 4646  79000000.0  7200.0       5.0        6.0                  other
# 2806  45000000.0  7115.0       4.0        4.0     Sector 48, Gurgaon
# 5294  39000000.0  7000.0       6.0        6.0                  other
# 5619  35000000.0  7000.0       6.0        5.0                  other
# 5689  55000000.0  7000.0       6.0        5.0                  other
# 6529  43000000.0  7000.0       7.0        7.0                  other
# 6836  40500000.0  7000.0       9.0        9.0                  other

# %%
data.shape
# Out:
# (6931, 7)

# %%
data
# Out:
#            price    area  Bedrooms  Bathrooms  type_of_building   Price_sqft  \
# 0      5500000.0  1146.0       2.0        2.0              Flat  4799.301920
# 1      6500000.0  1375.0       3.0        2.0              Flat  4727.272727
# 2      8000000.0  1605.0       3.0        3.0              Flat  4984.423676
# 3      7200000.0  1725.0       3.0        3.0  Individual House  4173.913043
# 4      6000000.0  1130.0       2.0        2.0              Flat  5309.734513
# ...          ...     ...       ...        ...               ...          ...
# 6926  20000000.0  2374.0       4.0        4.0              Flat  8424.599832
# 6927   4100000.0  1304.0       2.0        2.0              Flat  3144.171779
# 6928   3700000.0  1270.0       2.0        2.0              Flat  2913.385827
# 6929   4000000.0   700.0       2.0        2.0              Flat  5714.285714
# 6930   9500000.0  1850.0       3.0        3.0              Flat  5135.135135
#
#                        location
# ...

# %%
data.drop(columns=['Price_sqft'],inplace=True)

# %%
data.head()
# Out:
#        price    area  Bedrooms  Bathrooms  type_of_building  \
# 0  5500000.0  1146.0       2.0        2.0              Flat
# 1  6500000.0  1375.0       3.0        2.0              Flat
# 2  8000000.0  1605.0       3.0        3.0              Flat
# 3  7200000.0  1725.0       3.0        3.0  Individual House
# 4  6000000.0  1130.0       2.0        2.0              Flat
#
#                     location
# 0  Ahinsa Khand 1, Ghaziabad
# 1  Ahinsa Khand 1, Ghaziabad
# 2  Ahinsa Khand 1, Ghaziabad
# 3  Ahinsa Khand 1, Ghaziabad
# 4  Ahinsa Khand 1, Ghaziabad

# %%
data.to_csv("Cleaned_data.csv")

# %%
X=data.drop(columns=['price'])
y=data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5544, 5)
# (1387, 5)

# %%
column_trans = make_column_transformer(
    (
        OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
        ['location', 'type_of_building']
    ),
    remainder='passthrough'
)

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans, scaler, lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['location',
#                                                    'type_of_building'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr = pipe.predict(X_test)

# %%
print(r2_score(y_test, y_pred_lr))
# Out:
# 0.8607078600514695

# %%
print(pipe.score(X_train, y_train))
print(pipe.score(X_test, y_test))
# Out:
# 0.8702553547078311
# 0.8607078600514695

# %%
print(r2_score(y_test, y_pred_lr))
# Out:
# 0.8607078600514695

# %%
rf = RandomForestRegressor(n_estimators=100,random_state=0,n_jobs=-1)

# %%
pipe = make_pipeline(column_trans, rf)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['location',
#                                                    'type_of_building'])])),
#                 ('randomforestregressor',
#                  RandomForestRegressor(n_jobs=-1, random_state=0))])

# %%
y_pred = pipe.predict(X_test)

# %%
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# R² Score: 0.8608969710401844

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Saurav Kumar\delhi-house-predictor

# %%
import pickle

pickle.dump(pipe, open("DelhiHousePredictionModel.pkl", "wb"))

print("Delhi House Prediction Model saved successfully!")
# Out:
# Delhi House Prediction Model saved successfully!

# %%
ridge = Ridge(alpha=1.0)

# %%
pipe = make_pipeline(
    column_trans,
    StandardScaler(with_mean=False),
    ridge
)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['location',
#                                                    'type_of_building'])])),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('ridge', Ridge())])

# %%
y_pred = pipe.predict(X_test)

# %%
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# R² Score: 0.8607552891436843

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 1447412.742753489
# RMSE: 2242596.006019633
